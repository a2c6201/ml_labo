# %% [markdown]
# # グラフの描画

# %% [markdown]
# ## 3.1 二次元のグラフを描く
# ### ランダムなグラフを描く

# %%
# リスト　3-1-1

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# データ生成
np.random.seed(seed=1)
x = np.arange(10)
y = np.random.rand(10)

#
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 # リスト　3-1-1
# ----> 3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# File ~/miniforge3/envs/python38/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %% [markdown]
# ## 3.1.3 3次関数を描く
# f(x) = (x-2)x (x+2)

# %%
# リスト3-2-1
# %matplotlib inline
# import numpy as np
import matplotlib.pyplot as plt

# def f(x):
#   return (x - 2) * x * (x + 2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # リスト3-2-1
# ----> 2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 # import numpy as np
#       4 import matplotlib.pyplot as plt
#
# File ~/miniforge3/envs/python38/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
